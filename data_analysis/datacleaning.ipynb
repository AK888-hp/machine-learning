# %%
import seaborn as sns

# %%
df=sns.load_dataset("planets")

# %%
df.head()
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009

# %%
df.isnull()
# Out:
#       method  number  orbital_period   mass  distance   year
# 0      False   False           False  False     False  False
# 1      False   False           False  False     False  False
# 2      False   False           False  False     False  False
# 3      False   False           False  False     False  False
# 4      False   False           False  False     False  False
# ...      ...     ...             ...    ...       ...    ...
# 1030   False   False           False   True     False  False
# 1031   False   False           False   True     False  False
# 1032   False   False           False   True     False  False
# 1033   False   False           False   True     False  False
# 1034   False   False           False   True     False  False
#
# [1035 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# dtype: int64

# %%
df[df['mass'].isnull()]
# Out:
#                method  number  orbital_period  mass  distance  year
# 7     Radial Velocity       1      798.500000   NaN     21.41  1996
# 20    Radial Velocity       5        0.736540   NaN     12.53  2011
# 25    Radial Velocity       1      116.688400   NaN     18.11  1996
# 26    Radial Velocity       1      691.900000   NaN     81.50  2012
# 29            Imaging       1             NaN   NaN     45.52  2005
# ...               ...     ...             ...   ...       ...   ...
# 1030          Transit       1        3.941507   NaN    172.00  2006
# 1031          Transit       1        2.615864   NaN    148.00  2007
# 1032          Transit       1        3.191524   NaN    174.00  2007
# 1033          Transit       1        4.125083   NaN    293.00  2008
# 1034          Transit       1        4.187757   NaN    260.00  2008
#
# [522 rows x 6 columns]

# %%
df['mass'].isnull()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1030     True
# 1031     True
# 1032     True
# 1033     True
# 1034     True
# Name: mass, Length: 1035, dtype: bool

# %%
df['mass_mean']=df['mass'].fillna(df['mass'].mean())

# %%
df[['mass_mean','mass']]
# Out:
#       mass_mean   mass
# 0      7.100000   7.10
# 1      2.210000   2.21
# 2      2.600000   2.60
# 3     19.400000  19.40
# 4     10.500000  10.50
# ...         ...    ...
# 1030   2.638161    NaN
# 1031   2.638161    NaN
# 1032   2.638161    NaN
# 1033   2.638161    NaN
# 1034   2.638161    NaN
#
# [1035 rows x 2 columns]

# %%
sns.histplot(df['mass_mean'])
# Out:
# <Axes: xlabel='mass_mean', ylabel='Count'>

# %%
df[df.isnull()]
# Out:
#      method  number  orbital_period  mass  distance  year  mass_mean
# 0       NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 1       NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 2       NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 3       NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 4       NaN     NaN             NaN   NaN       NaN   NaN        NaN
# ...     ...     ...             ...   ...       ...   ...        ...
# 1030    NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 1031    NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 1032    NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 1033    NaN     NaN             NaN   NaN       NaN   NaN        NaN
# 1034    NaN     NaN             NaN   NaN       NaN   NaN        NaN
#
# [1035 rows x 7 columns]

# %%
df.isnull().sum()
# Out:
# method              0
# number              0
# orbital_period     43
# mass              522
# distance          227
# year                0
# mass_mean           0
# dtype: int64

# %%
df['distance_median']=df['distance'].fillna(df['distance'].median)

# %%
df[['distance_median','distance']]
# Out:
#      distance_median  distance
# 0               77.4     77.40
# 1              56.95     56.95
# 2              19.84     19.84
# 3             110.62    110.62
# 4             119.47    119.47
# ...              ...       ...
# 1030           172.0    172.00
# 1031           148.0    148.00
# 1032           174.0    174.00
# 1033           293.0    293.00
# 1034           260.0    260.00
#
# [1035 rows x 2 columns]

# %%
df['distance'].isnull().sum()
# Out:
# np.int64(227)

# %%
df['distance_median'].isnull().sum()
# Out:
# np.int64(0)
